# %% [markdown]
# <a href="https://colab.research.google.com/github/akshas-25/NLP-Learnings/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train.txt',sep=';',header=None,names=['text','emotion'])

# %%
df.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
df.isnull().sum()
# Out:
# text       0
# emotion    0
# dtype: int64

# %%
df['emotion'].unique() #all the emotions present in the dataset
# Out:
# array(['sadness', 'anger', 'love', 'surprise', 'fear', 'joy'],
#       dtype=object)

# %%
unique_emotions=df['emotion'].unique()

# %%
print(unique_emotions) #makes an array of the emotions
# Out:
# ['sadness' 'anger' 'love' 'surprise' 'fear' 'joy']

# %%
emotion_numbers={} #made a dictionary to map the emotions to numbers like sadness=0
i=0
for emo in unique_emotions:
  emotion_numbers[emo]=i
  i+=1
df['emotion']=df['emotion'].map(emotion_numbers) #mapped out all the emotions in the dataset to their emotion number

# %%
df
# Out:
#                                                     text  emotion
# 0                                i didnt feel humiliated        0
# 1      i can go from feeling so hopeless to so damned...        0
# 2       im grabbing a minute to post i feel greedy wrong        1
# 3      i am ever feeling nostalgic about the fireplac...        2
# 4                                   i am feeling grouchy        1
# ...                                                  ...      ...
# 15995  i just had a very brief time in the beanbag an...        0
# 15996  i am now turning and i feel pathetic that i am...        0
# 15997                     i feel strong and good overall        5
# 15998  i feel like this was such a rude comment and i...        1
# 15999  i know a lot but i feel so stupid because i ca...        0
#
# [16000 rows x 2 columns]

# %%
df['text']=df['text'].apply(lambda x: x.lower()) #make it into lowercase

# %%
import string #make a function to remove punctionations
def remove_punc(txt):
  return txt.translate(str.maketrans('','',string.punctuation))

# %%
df['text']=df['text'].apply(remove_punc) #apply that fuction to the data

# %%
def remove_num(txt):
  new=""
  for i in txt:
    if not i.isDigit():
      new=new+i
  return new

# %%
def remove_num(txt): #make a func to remove the digits
  new=""
  for i in txt:
    if not i.isdigit():
      new=new+i
  return new
df['text']=df['text'].apply(remove_num)

# %%
def remove_emojis(txt):#remove emojis
  new =""
  for i in txt:
    if not i.isascii(): #emojis have unicodes so we are trying to keep only those characters that have ascii values
      new=new+i
  return new
df['text']=df['text'].apply(remove_emojis)

# %%
# 5. Define and apply function to remove emojis (corrected logic)
def remove_emojis(txt):
  new =""
  for i in txt:
    if i.isascii(): # Keep only those characters that have ascii values, effectively removing emojis
      new=new+i
  return new
df['text']=df['text'].apply(remove_emojis)

# %%
# 6. Define and apply function to remove stopwords
# Ensure NLTK resources are downloaded (quietly to avoid repeated output)
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('punkt_tab', quiet=True) # Ensure punkt_tab is downloaded
# Out:
# True

# %%
stop_words=set(stopwords.words('english'))

def remove(txt):
  # Ensure the text is not empty before tokenizing
  if not txt.strip(): # Check for empty or whitespace-only strings
    return ""
  words=word_tokenize(txt)
  new_words=[]
  for w in words:
    if w not in stop_words:
      new_words.append(w)
  return " ".join(new_words)

df['text']=df['text'].apply(remove)

# Display the cleaned DataFrame head to verify
display(df.head())
# Out:
#                                                 text  emotion
# 0                              didnt feel humiliated        0
# 1  go feeling hopeless damned hopeful around some...        0
# 2          im grabbing minute post feel greedy wrong        1
# 3  ever feeling nostalgic fireplace know still pr...        2
# 4                                    feeling grouchy        1
